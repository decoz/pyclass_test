# %% [markdown]
# ## 푸시기 전에 ..
#
# ```
# #### 중간고사 규칙:
# - 중간고사는 오픈북 형태로서 수업시간 자료와 외부 자료를 모두 조회, 참고 가능합니다.
# - 인터넷 검색도 가능하지만 타인과의 정보교환은 엄격히 금합니다. 적발시 바로 부정행위로 조치합니다.
# - 수험 시간은 3시 20분까지입니다.
# - 점수는 작성하신 프로그램중에 가장 난이도가 높은 프로그램으로 반영됩니다. 그러므로 가장 난이도가 높은 프로그램 하나만 정확히 작성하셔도 만점입니다.
# - 쉬운 프로그램을 채점 받은 후에 다시 난이도 높은 프로그램을 재 채점 받으셔도 됩니다.
# ```

# %% [markdown]
# <hr>
#
# # 2021 학년도 컴퓨터실습2 중간고사 (실습2과정)
# <br>
#
# #### 문제 1. 임의의 문자열에 빈칸이 있을 경우 줄을 바꿔 줄력하도록 하세요 [30점]
# ```
# 예:
# "A piece of  cake"
# ->
# A
# piece
# of
#
# cake
# ```

# %%
s = "A piece of  cake"

# 문제 1 코드를 작성하세요
for c in s:
  if c == ' ':
    print()
  else :
    print(c, end = '')
# Out:
# A
# piece
# of
#
# cake

# %% [markdown]
# <Br><Br><Br>
#
# #### 문제 2. 99단의 n 단까지를 입력받아 다음과 같이 출력하는 print99(n) 함수를 생성하세요 [40점]
# ```
# 예 :
# print99(3)
# ->
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
#
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
#
# ```

# %%
def print99(n):
  _
  # 문제 2의 코드를 작성하세요  
  for ni in range(2, n+1):
    for i in range(2,10):
      print(ni, "x", i, "=", ni * i)
    print()
  
aㅅprint99(3)
# Out:
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
#
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27

# %% [markdown]
# ##<font color = 'red'> <문제 3-4번용 이미지 로딩 >
#
# 아래에는 이미지문제를 위해 시험용 샘플이미지 로딩 코드입니다.  아래 문제를 풀기전에 반드시 실행하고 시작해주세요
# </font>

# %%
from PIL import Image
from IPython.display import display
import numpy as np 
from urllib import request

# 이미지 열고 출력
img = Image.open(request.urlopen("https://github.com/decoz/pyclass_test/blob/main/images/cat.jpg?raw=true") )
display(img)
print("size:",img.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F4BA33F4E50>
# size: (256, 256)

# %% [markdown]
# <Br><Br><Br>
#
# #### 문제 3. 위의 이미지에 아래와 같이 10칸 단위의 대각선으로 하얀 선을 그어보세요 [50점]
#
# <img src = "https://github.com/decoz/pyclass_test/blob/main/images/cat_hatch.png?raw=true">

# %%
# 이미지를 2차원 배열 arr로 변경
w,h = img.size
arr = np.array(img).reshape(h, w, 3)

# 문제 3의 코드를 작성하세요
for y in range(h):
  for x in range(w):
    if (x + y) % 10 == 0 :
      arr[y][x] = [255,255,255]

# arr 을 다시 이미지로 출력
display(Image.fromarray(arr))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F4B9C643F50>

# %% [markdown]
# <Br><Br><Br>
#
# #### 문제 4. 이미지를 n개를 옆으로 복사하는 함수 dupImage(img, n) 을 만들어보세요 [60점]
# ```
# 예:
# dupImage(img, 4)
# ```
#
# ```
# > 참고 : 크기가 w, h  인 새로운 빈 이미지 배열을 손쉽게 만드는 방법
# narr = np.zeros((w,h,3)).astype('uint8')
# ```

# %%
def dupImage(img, n):
  _
  # 문제 4의 코드를 작성하세요

  # 배열 변환 
  w,h = img.size
  arr = np.array(img).reshape(h, w, 3)

  # 출력용 배열 생성
  narr = np.zeros((h,w*n,3)).astype('uint8')

  # 이미지 복사  
  for y in range(h):
    for x in range(w):
      # n 번만큼 옆으로 픽셀값을 복사
      for i in range(n):        
        narr[y][x + i*w] = arr[y][x]  

  # 출력
  display(Image.fromarray(narr))

#호출
dupImage(img,4)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x256 at 0x7F4B9D33FBD0>

# %% [markdown]
# ### 제출 시 참고 :
# - 과제 제출은 작성하신 colab을 [파일 > 다운로드 > ipynb] 메뉴를 통해 파일로 다운 받으신 후에 사이버캠퍼스 [중간고사 제출] 이라는 과제에 업로드하셔야 합니다.
# - 웹브라우저(크롬, ie, 엣지 파폭)의 메뉴가 아닌 colab 에 있는 다운로드를 사용하셔야 정상적으로 ipynb 로 다운로드 됩니다.
