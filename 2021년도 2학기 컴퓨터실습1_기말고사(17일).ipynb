# %% [markdown]
# # 2021 학년도 1학기 컴퓨터실습 기말고사
#
# ```
# #### 기말고사 규칙:
# - 라이브러리나 함수의 도움 없이 기본적인 문법으로 문제를 해결하셔야합니다. 타입변환(str, int등), 배열의 카피(arr.copy()) 등 수업시간에 사용된 함수는 가능합니다.
# - 푸신 문제중에 가장 난이도가 높은 문제를 기준으로 점수 평가가 됩니다.
# - 최고 난이도 한 문제만 푸셔도 만점입니다.
# - 한 문제에 매달리다 실패하는 위험을 줄이기 위해 자신있는 문제를 먼저 푸시고 도전할만한 문제를 푸시는걸 추천드립니다.
# - 소스를 실행했을때 실행이 되어야 합니다.
# - 수험 시간은 시작 이후 1시간 20분까지입니다.
# - 반드시 ipynb 파일로 다운받아 과제에 업로드하셔야 합니다.
# - 수업시간에 알려드린 방식과 다르거나 지나치게 유사한 답안이 존재할 경우  본인이 푸신걸 확인하기 위한 절차를 요청할 수 있습니다. 이때 설명을 못하시면 부정시험으로 간주합니다.
# ```
#  <hr>

# %% [markdown]
# ## 배열 관련
#
#
# #### 문제 1 : 임의의 배열에서 홀수번째 값들의 합산 값을 출력하세요 [60점]
#
# 예
# ```
# arr = [1,4,2,3,5]
#
# # 1 + 2 + 5
# -> 8
#
# arr = [1,4,2,5,7,10,8]
#
# # 1 + 2 + 7 + 8
# -> 18
#
# ```

# %%
# 배열의 크기와 값를 바꾸며 테스트해보세요
arr = [1,4,2,5,7,10,8]

# 문제 1의 코드를 작성하세요

# %% [markdown]
# <Br><Br><Br>
# #### 문제 2 : 5,5 인 임의의 2차원 배열에서 각 열의 합산값을 배열로 생성하세요[70점]
#
# 예:
# ```
# [ [0,4,1,3,5],
#   [1,2,5,2,7],
#   [2,3,2,1,4],
#   [1,4,2,3,6],
#   [8,9,1,2,3]
# ]
#
# ->
#   # 0 + 1 + 2 + 1 + 8 -> 12
#   # 4 + 2 + 3 + 4 + 9 -> 22
#   ...
#   # 5 + 7 + 4 + 6 + 3 -> 25
#
# 출력 :
# [12, 22, 11, 11, 25]
# ```

# %%
# 예제 배열
arr = [ [0,4,1,3,5],
        [1,2,5,2,7],
        [2,3,2,1,4],
        [1,4,2,3,6],
        [8,9,1,2,3]
      ]

sum = [0,0,0,0,0]
# 문제2의 코드를 작성하세요


# 출력 구문
print(sum)

# %% [markdown]
# <Br><Br><Br>
# #### 문제 3 : 다음과 같은 배열의 생성하세요 [80점]
#
# 예
# ```
# [0, 1, 0, 1, 0, 1, 0, 1, 0]
# [0, 2, 0, 2, 0, 2, 0, 2, 0]
# [0, 3, 0, 3, 0, 3, 0, 3, 0]
# [0, 4, 0, 4, 0, 4, 0, 4, 0]
# [0, 5, 0, 5, 0, 5, 0, 5, 0]
# [0, 6, 0, 6, 0, 6, 0, 6, 0]
# [0, 7, 0, 7, 0, 7, 0, 7, 0]
# [0, 8, 0, 8, 0, 8, 0, 8, 0]
# ```

# %%
# 문제 2의 코드를 여기에 작성하세요

# 출력
for v in arr:
  print(v)

# %% [markdown]
# <Br><Br><Br>
# <hr>
#
# ##  이미지 관련
#
# 아래는 크기가 100x100 인 0으로 가득찬 2차원 배열을 생성해 이미지로 표현하는 코드입니다. 먼저 이를 실행한 후에 아래의 문제를 풀어보세요.

# %%
from PIL import Image
from IPython.display import display
import numpy as np

arr = [] 
for i in range(100):
  tarr = []
  for j in range(100):
    tarr = tarr + [0] 
  arr = arr + [tarr]

display( Image.fromarray( np.array(arr).astype('uint8').reshape(100,100) , 'L' ) )

# %% [markdown]
# <Br>
#
# #### 문제 4 : 다음 그림과 같이 세로 줄의 간격이 1에서 시작해서 점점 1씩 커지도록 이미지의 배열을 변환하세요 [90점]
#
# <img src = 'http://drive.google.com/uc?export=view&id=1f817TCWIIE_IO5cGaGAk8kz4dFFXu-6B'>

# %%
# 배열 값 초기화
for x in range(100):
  for y in range(100):
    arr[y][x] = 0 

# 문제 4의 코드를 작성하세요


# 출력
display( Image.fromarray( np.array(arr).astype('uint8').reshape(100,100) , 'L' ) )

# %% [markdown]
# <Br><Br><Br>
#
# #### 문제 5 : 아래와 같은 이미지가 출력되도록 이미지 배열의 값을 바꾸세요 [100점]
#
# <img src='http://drive.google.com/uc?export=view&id=1WUbFZOGo_RTFUrAconPJzPAvW0XOIXIK' /><br>

# %%
# 배열 값 초기화
for x in range(100):
  for y in range(100):
    arr[y][x] = 0 

# 문제 5의 코드를 작성하세요





# 이미지로 출력
display( Image.fromarray( np.array(arr).astype('uint8') , 'L' ) )
